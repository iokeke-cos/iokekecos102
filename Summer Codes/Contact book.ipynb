# %%
from tkinter import *
import sys

win = Tk()
win.title("Contact Book")
win.geometry("700x500+200+20")

win.minsize(700,500)
win.maxsize(700,500)
win.config(bg="gray10")

sys.path.append('C:/Users/User/Desktop/iokekecos102(python)/Summer Codes/def_phonebook')

menubar = Menu(win)
filemenu = Menu(menubar,tearoff = 0)
filemenu.add_separator()
filemenu.add_command(label = 'See',command = lambda : see(win))
filemenu.add_separator()
filemenu.add_command(label = 'Save',command = lambda : save(win))
filemenu.add_separator()
filemenu.add_command(label = 'Make Excel File',command = lambda : excel_file(win))
filemenu.add_separator()
filemenu.add_command(label = 'Search',command = lambda : search(win))
filemenu.add_separator()
filemenu.add_command(label = 'Exit',command = lambda : win.destroy)
filemenu.add_separator()

menubar.add_cascade(label = "file",menu = filemenu)

editmenu = Menu(menubar,tearoff = 0)
editmenu.add_separator()
editmenu.add_command(label = "Add",command = lambda : add(win))
editmenu.add_separator()
editmenu.add_command(label = "Remove",command = lambda : remove(win))
editmenu.add_separator()


menubar.add_cascade(label = "Edit",menu = editmenu)

win.config(menu=menubar)

mainloop()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[21], line 2
#       1 from tkinter import *
# ----> 2 import def_phonebook.ipynb
#       3 import sys
#       5 win = Tk()
#
# File ~\Desktop\iokekecos102(python)\Summer Codes\def_phonebook.py:97
#       1 {
#       2  "cells": [
#       3   {
#       4    "cell_type": "code",
#       5    "execution_count": 1,
#       6    "id": "2bce6f23-2f3f-4b49-a249-ee6f27c335cf",
#       7    "metadata": {},
#       8    "outputs": [],
#       9    "source": [
#      10     "import numpy as np\n",
#      11     "import pandas as pd\n",
#      12     "from tkinter import *\n",
#      13     "from tkinter import simpledialog\n",
#      14     "\n",
#      15     "## To load a saved file\n",
#      16     "\n",
#      17     "main = np.load(\"Contact Book.npy\",allow_pickle=True)\n",
#      18     "\n",
#      19     "def label(master,text=\"nothing\",x=0 , y=0):\n",
#      20     "    list_area = Label(master,text=text,bg = \"gray20\",\n",
#      21     "                      font=(\"times of roman\",15),fg = \"white\",\n",
#      22     "                      pady = 10)\n",
#      23     "\n",
#      24     "    list_area.place(x=x,y=y)\n",
#      25     "\n",
#      26     "def add(master):\n",
#      27     "    global main\n",
#      28     "    name = simpledialog.askstring(title = \"Name of the new contact\",prompt= \"Write Name pf New Contact\")\n",
#      29     "    num = simpledialog.askstring(title = \"Number pf new contact\",prompt= \"Write Number of New Contact\")\n",
#      30     "    add_array = np.array([name,num],dtype=object)\n",
#      31     "    main = np.vstack((main,add_array))\n",
#      32     "    label(master=master,text = add_array[0]+\"'s number is added to the list              \", x= 10, y=410)\n",
#      33     "    return main\n",
#      34     "\n",
#      35     "def save (master):\n",
#      36     "    label(master=master,text = \"Saving.....                     \",x= 10, y=410)\n",
#      37     "    np.save(\"contacts\", main)\n",
#      38     "    label(master=master,text = \"File is saved.                  \",x= 10, y=410)\n",
#      39     "\n",
#      40     "\n",
#      41     "\n",
#      42     "def excel_file(master):\n",
#      43     "    label(master=master,text = \"saving.......\")\n",
#      44     "    df  = pd.DataFrame(main)\n",
#      45     "    filepath = 'excel_contacts.xlsx'\n",
#      46     "    df.to_excel(filepath,index=False)\n",
#      47     "    label(master=master,text=\"File is saved as excel file.\",x= 10, y=410)\n",
#      48     "\n",
#      49     "\n",
#      50     "def see(master):\n",
#      51     "    text =Text(master)\n",
#      52     "    text.grid(row = 0,column = 1)\n",
#      53     "    scrollbar = Scrollbar(master,command = text.yview)\n",
#      54     "    text.config(yscrollcommand=scrollbar.set)\n",
#      55     "    scrollbar.grid(row=0,column=0,sticky=\"nsew\")\n",
#      56     "    text.insert(END,main)\n",
#      57     "\n",
#      58     "def search(master):\n",
#      59     "    s= list(main[:,0])\n",
#      60     "    n= simpledialog.askstring(title =\"Type name\", prompt =\"Type name \")\n",
#      61     "    lis = []\n",
#      62     "    for i,elem in enumerate(s):\n",
#      63     "        if n in elem:\n",
#      64     "            no = s.index(elem)\n",
#      65     "            ad = str(f\" {main[no,0]} -- {main[no,1]}   \")\n",
#      66     "            lis.append(ad)\n",
#      67     "\n",
#      68     "    text = Text(master)\n",
#      69     "    text.grid(row = 0,column=1)\n",
#      70     "    scrollbar = Scrollbar(master,command= text.yview)\n",
#      71     "    lis = np.array([lis],dtype = object)\n",
#      72     "    text.insert(END,lis)\n",
#      73     "\n",
#      74     "\n",
#      75     "\n",
#      76     "def remove(master):\n",
#      77     "    global main\n",
#      78     "    main_list = list(main[:,0])\n",
#      79     "\n",
#      80     "\n",
#      81     "    remove_name = simpledialog.askstring(title = \"searching a name to remove.........\",\n",
#      82     "                                       prompt = \"Search a name to remove\")\n",
#      83     "\n",
#      84     "    lis = []\n",
#      85     "    for i,elem in enumerate(main_list):\n",
#      86     "        if remove_name in elem:\n",
#      87     "            elem_no = main_list.index(elem)\n",
#      88     "            ad = str(f'       {main[elem_no,0]}-- main[')\n",
#      89     "\n",
#      90     "\n",
#      91     "\n",
#      92     "  "
#      93    ]
#      94   },
#      95   {
#      96    "cell_type": "code",
# ---> 97    "execution_count": null,
#      98    "id": "4d738b97-a3de-4de6-8918-31376cbb5f11",
#      99    "metadata": {},
#     100    "outputs": [],
#     101    "source": []
#     102   },
#     103   {
#     104    "cell_type": "code",
#     105    "execution_count": null,
#     106    "id": "200945a6-9e62-4eac-8687-6f6ae4124019",
#     107    "metadata": {},
#     108    "outputs": [],
#     109    "source": []
#     110   }
#     111  ],
#     112  "metadata": {
#     113   "kernelspec": {
#     114    "display_name": "Python 3 (ipykernel)",
#     115    "language": "python",
#     116    "name": "python3"
#     117   },
#     118   "language_info": {
#     119    "codemirror_mode": {
#     120     "name": "ipython",
#     121     "version": 3
#     122    },
#     123    "file_extension": ".py",
#     124    "mimetype": "text/x-python",
#     125    "name": "python",
#     126    "nbconvert_exporter": "python",
#     127    "pygments_lexer": "ipython3",
#     128    "version": "3.11.7"
#     129   }
#     130  },
#     131  "nbformat": 4,
#     132  "nbformat_minor": 5
#     133 }
#
# NameError: name 'null' is not defined
