# %%
#project_1
from tkinter import *
from openpyxl import load_workbook

root = Tk()
root.title("GIG-Logistics Staff Identifier")
root.geometry("500x500")

#Load existing workbook
wb = load_workbook('c:/Users/User/Desktop/Coding stuff/GIG-logistics.xlsx')


 #craete active worksheet
ws = wb.active

#creating variables for condition
condition_a = ws["row 14","row 16","row 17","row 31","row 32","row 41"]
condition_b = ws["row 3","row 5","row 7","row 13","row 20","row 21","row 26","row 27","row 28","row 34","row 35","row 36"]
condition_c = ws["row 4","row 9","row 10","row 11","row 15","row 22","row 23","row 29","row 30","row 39","row 40" ]
condition_d = ws["row 2","row 6","row 8","row 12","row 18","row 19","row 24","row 25","row 33","row 37","row 38"]


cond_a = str(condition_a)
cond_b = str(condition_b)
cond_c = str(condition_c)
cond_d = str(condition_d)
#action for button
  
def button_click():
    a = staff_firstname.get()
    b = staff_lastname.get()
    department = staff_department.get()
    Label_1 = tk.Label(root,text = "Loading Entry....")
    Label_1.pack()


#condition statement for information access
for all in ws:
    if a  in ws and b  in ws:
      welcome_label =tk.Label(root, text="WELCOME EMPLOYEE!")
      label_2 = tk.Label(root,text = "Access Granted")
      label_2.pack()
                        
    else:
      messagebox.showerror("Access Denied...Employee does not exist")



  
if department == "administration":
   print(cond_a)

 
elif department == "accounting":
   print(cond_b)

  
if department == "Delivery":
   print(cond_c)

  
elif department == "Logistics":
   print(cond_d)
   
 
    

#Defining button
button = tk.Button(root,text = "Access",padx=5,pady =3,bg="black",fg="white",command=button_click)
button.pack()

#making input
staff_lastname_label = tk.Label(root,text=" Enter Your Last Name (All Capital Letters )")
staff_lastname = tk.Entry(root).pack()
staff_firstname_label = tk.Label(root,text=" Enter Your First Name(First letter in caps)")
staff_firstname = tk.Entry(root).pack()
staff_department_label = tk.Label(root,text="Enter Your Department")
staff_department = tk.Entry(root).pack()


root.mainloop()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[57], line 17
#      14 ws = wb.active
#      16 #creating variables for condition
# ---> 17 condition_a = ws["row 14","row 16","row 17","row 31","row 32","row 41"]
#      18 condition_b = ws["row 3","row 5","row 7","row 13","row 20","row 21","row 26","row 27","row 28","row 34","row 35","row 36"]
#      19 condition_c = ws["row 4","row 9","row 10","row 11","row 15","row 22","row 23","row 29","row 30","row 39","row 40" ]
#
# File ~\anaconda3\Lib\site-packages\openpyxl\worksheet\worksheet.py:290, in Worksheet.__getitem__(self, key)
#     287 if isinstance(key, int):
#     288     key = str(key
#     289               )
# --> 290 min_col, min_row, max_col, max_row = range_boundaries(key)
#     292 if not any([min_col, min_row, max_col, max_row]):
# ...
