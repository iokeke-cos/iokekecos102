# %%
#project_1
from tkinter import  *
import tkinter as tk
from tkinter import messagebox
root = tk.Tk()
root.title("Simi Services")
root.geometry("400x400")


#define button action
def button_click() :
    #package_number=package_number.get()
    location_entry=location_entry.get()
    weight_entry=weight_entry.get(int)  
    label =tk.Label(root,text ="Processing...")
    label.pack() 

#creating condition
    
    
if location_entry == "Ibeju-Lekki" and weight_entry >= 10:
     print("Your Delivery fee is N5,000")
     print(package_number)
else:
     messagebox.showerror("Login","Sorry.....We do not offer services in your area,contact..08034837265..for more details")
    
if location_entry == "Ibeju-Lekki" and weight_entry < 10:
     print("Your Delivery fee is N3,500")
     print(package_number)
else:
     messagebox.showerror("Login","Sorry.....We do not offer services in your area,contact..08034837265..for more details")
    

if  location_entry == "Epe" and weight_entry >= 10:
     print("Your Delivery fee is N10,000")
     print(package_number)

elif location_entry == "Epe" and weight_entry < 10:
     print("Your Delivery fee is N5,000")
     print(package_number)
else:
     messagebox.showerror("Login","Sorry.....We do not offer services in your area,contact..08034837265..for more details")


#create input
package_number_label= tk.Label(root,padx=10,text="Please enter your package number:").pack()
package_number = tk.Entry(root,bg="white",fg="blue").pack()
location_entry_label =tk.Label(root,padx=8,text ="Please enter location:").pack()
location_entry = tk.Entry(root,bg="white",fg="blue").pack()
weight_entry_label = tk.Label(root,padx=5,text="Please enter the weight of your package(in kg):").pack()
weight_entry= tk.Entry(root,bg = "white",fg="blue").pack()

#create button
button = tk.Button(root,text="Submit Information",padx = 7,pady=4,bg="white",fg="blue",command=button_click)
button.pack()




root.mainloop()
# Out:
# Exception in Tkinter callback
# Traceback (most recent call last):
#   File "C:\Users\User\anaconda3\Lib\tkinter\__init__.py", line 1948, in __call__
#     return self.func(*args)
#            ^^^^^^^^^^^^^^^^
#   File "C:\Users\User\AppData\Local\Temp\ipykernel_24580\3303288319.py", line 13, in button_click
#     location_entry=location_entry.get()
#                    ^^^^^^^^^^^^^^
# UnboundLocalError: cannot access local variable 'location_entry' where it is not associated with a value

# %%
#project_2
from tkinter import *
root = Tk()
root.title("University Student Portal ")
root.geometry("500x500")

#create input/array


#create button

#define button


#define conditions


#end event loop
root.mainloop()
